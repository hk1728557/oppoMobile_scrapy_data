# %%
from scrapy.selector import Selector
from tqdm import tqdm
from nested_lookup import nested_lookup
import json
import hjson
import lxml.html.clean
from bs4 import BeautifulSoup
import re
import time
import pandas as pd

# %%
import requests

cookies = {
    '_fbp': 'fb.1.1670093931125.1066583101',
    '_gcl_au': '1.1.2111261605.1670093931',
    '_ga': 'GA1.2.1482551647.1670093931',
    '_gid': 'GA1.2.310018717.1670093931',
    '_hjSessionUser_2526921': 'eyJpZCI6IjJmOGFiZTVhLTAzNWMtNWE4Zi05YzY0LWVmZjhkYTFlNzMzMyIsImNyZWF0ZWQiOjE2NzAwOTM5MzA4MDAsImV4aXN0aW5nIjp0cnVlfQ==',
    'css_first_load': '1',
    'ciccratchcoupon': '%5B%5D',
    'form_key': 'YOxDtVwqt8GnnBJf',
    'cdz-newsletter-modal': '1lax',
    'PHPSESSID': '1alid9cu064qlgltblik2rggel',
    'form_key': 'YOxDtVwqt8GnnBJf',
    'mage-cache-storage': '%7B%7D',
    'mage-cache-storage-section-invalidation': '%7B%7D',
    'mage-cache-sessid': 'true',
    'searchsuiteautocomplete': '%7B%7D',
    'recently_viewed_product': '%7B%7D',
    'recently_viewed_product_previous': '%7B%7D',
    'recently_compared_product': '%7B%7D',
    'recently_compared_product_previous': '%7B%7D',
    'product_data_storage': '%7B%7D',
    'section_data_ids': '%7B%22cart%22%3A1670249243%7D',
    '_hjIncludedInSessionSample': '0',
    '_hjSession_2526921': 'eyJpZCI6ImQxOGU3YjlmLTc0ZWQtNDY4ZS1hNGNlLTdlMzUzOGNhYmEzOSIsImNyZWF0ZWQiOjE2NzAyNTIzNzEzMjIsImluU2FtcGxlIjpmYWxzZX0=',
    '_hjAbsoluteSessionInProgress': '0',
    'private_content_version': '2a1ec34197547510397823f82e512e07',
}

headers = {
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Accept-Language': 'en-GB,en-US;q=0.9,en;q=0.8',
    'Cache-Control': 'max-age=0',
    'Connection': 'keep-alive',
    # 'Cookie': '_fbp=fb.1.1670093931125.1066583101; _gcl_au=1.1.2111261605.1670093931; _ga=GA1.2.1482551647.1670093931; _gid=GA1.2.310018717.1670093931; _hjSessionUser_2526921=eyJpZCI6IjJmOGFiZTVhLTAzNWMtNWE4Zi05YzY0LWVmZjhkYTFlNzMzMyIsImNyZWF0ZWQiOjE2NzAwOTM5MzA4MDAsImV4aXN0aW5nIjp0cnVlfQ==; css_first_load=1; ciccratchcoupon=%5B%5D; form_key=YOxDtVwqt8GnnBJf; cdz-newsletter-modal=1lax; PHPSESSID=1alid9cu064qlgltblik2rggel; form_key=YOxDtVwqt8GnnBJf; mage-cache-storage=%7B%7D; mage-cache-storage-section-invalidation=%7B%7D; mage-cache-sessid=true; searchsuiteautocomplete=%7B%7D; recently_viewed_product=%7B%7D; recently_viewed_product_previous=%7B%7D; recently_compared_product=%7B%7D; recently_compared_product_previous=%7B%7D; product_data_storage=%7B%7D; section_data_ids=%7B%22cart%22%3A1670249243%7D; _hjIncludedInSessionSample=0; _hjSession_2526921=eyJpZCI6ImQxOGU3YjlmLTc0ZWQtNDY4ZS1hNGNlLTdlMzUzOGNhYmEzOSIsImNyZWF0ZWQiOjE2NzAyNTIzNzEzMjIsImluU2FtcGxlIjpmYWxzZX0=; _hjAbsoluteSessionInProgress=0; private_content_version=2a1ec34197547510397823f82e512e07',
    'Referer': 'https://www.google.com/',
    'Sec-Fetch-Dest': 'document',
    'Sec-Fetch-Mode': 'navigate',
    'Sec-Fetch-Site': 'cross-site',
    'Sec-Fetch-User': '?1',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Mobile Safari/537.36',
    'sec-ch-ua': '"Not?A_Brand";v="8", "Chromium";v="108", "Google Chrome";v="108"',
    'sec-ch-ua-mobile': '?1',
    'sec-ch-ua-platform': '"Android"',
}

response = requests.get(
    'https://www.poojaratele.com/oppo-smartwatch-46mm-wifi-glossy-gold.html',
    cookies=cookies,
    headers=headers,
)

# %%
response.text
# Out:
# '<!doctype html>\n<html lang="en">\n    <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# product: http://ogp.me/ns/product#">\n        <script>\n    var BASE_URL = \'https\\u003A\\u002F\\u002Fwww.poojaratele.com\\u002F\';\n    var require = {\n        \'baseUrl\': \'https\\u003A\\u002F\\u002Fwww.poojaratele.com\\u002Fstatic\\u002Fversion1666166925\\u002Ffrontend\\u002FCodazon\\u002Funlimited_food_drink\\u002Fen_US\'\n    };</script>        <meta charset="utf-8"/>\n<meta name="title" content="Buy OPPO Watch 46 mm WiFi Smartwatch online at Poojaratele.com"/>\n<meta name="description" content="OPPO Watch 46mm WiFi Smartwatch at best prices &amp; cash on delivery from Poojara Telecom, Only Genuine Products."/>\n<meta name="keywords" content="oppo watch (46mm), oppo watch (46mm) price, buy oppo watch (46mm), buy oppo watch (46mm) online, oppo watch (46mm) price in india, oppo watch (46mm) best price, oppo watch (46mm) offers"/>\n<meta name="robots" content="INDEX,FOLLOW"/>\n<m
# ...

# %%
sel = Selector(response)
sel
# Out:
# <Selector xpath=None data='<html lang="en">\n    <head prefix="og...'>

# %%
spec_titles = sel.xpath('//*/h1[contains(@class,"page-title")]//text()').extract()
spec_skus = sel.xpath('//*/div[contains(@class,"product attribute sku")]/div/text()').extract()
spec_titles
spec_skus
# Out:
# ['6944284667150']

# %%
def get_res(url):
    cookies = {
    '_fbp': 'fb.1.1670093931125.1066583101',
    '_gcl_au': '1.1.2111261605.1670093931',
    '_ga': 'GA1.2.1482551647.1670093931',
    '_gid': 'GA1.2.310018717.1670093931',
    '_hjSessionUser_2526921': 'eyJpZCI6IjJmOGFiZTVhLTAzNWMtNWE4Zi05YzY0LWVmZjhkYTFlNzMzMyIsImNyZWF0ZWQiOjE2NzAwOTM5MzA4MDAsImV4aXN0aW5nIjp0cnVlfQ==',
    'css_first_load': '1',
    'ciccratchcoupon': '%5B%5D',
    'form_key': 'YOxDtVwqt8GnnBJf',
    'cdz-newsletter-modal': '1lax',
    'PHPSESSID': '1alid9cu064qlgltblik2rggel',
    'form_key': 'YOxDtVwqt8GnnBJf',
    'mage-cache-storage': '%7B%7D',
    'mage-cache-storage-section-invalidation': '%7B%7D',
    'mage-cache-sessid': 'true',
    'searchsuiteautocomplete': '%7B%7D',
    'recently_viewed_product': '%7B%7D',
    'recently_viewed_product_previous': '%7B%7D',
    'recently_compared_product': '%7B%7D',
    'recently_compared_product_previous': '%7B%7D',
    'product_data_storage': '%7B%7D',
    'section_data_ids': '%7B%22cart%22%3A1670249243%7D',
    '_hjIncludedInSessionSample': '0',
    '_hjSession_2526921': 'eyJpZCI6ImQxOGU3YjlmLTc0ZWQtNDY4ZS1hNGNlLTdlMzUzOGNhYmEzOSIsImNyZWF0ZWQiOjE2NzAyNTIzNzEzMjIsImluU2FtcGxlIjpmYWxzZX0=',
    '_hjAbsoluteSessionInProgress': '0',
    'private_content_version': '2a1ec34197547510397823f82e512e07',
}
    headers = {
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Accept-Language': 'en-GB,en-US;q=0.9,en;q=0.8',
    'Cache-Control': 'max-age=0',
    'Connection': 'keep-alive',
    # 'Cookie': '_fbp=fb.1.1670093931125.1066583101; _gcl_au=1.1.2111261605.1670093931; _ga=GA1.2.1482551647.1670093931; _gid=GA1.2.310018717.1670093931; _hjSessionUser_2526921=eyJpZCI6IjJmOGFiZTVhLTAzNWMtNWE4Zi05YzY0LWVmZjhkYTFlNzMzMyIsImNyZWF0ZWQiOjE2NzAwOTM5MzA4MDAsImV4aXN0aW5nIjp0cnVlfQ==; css_first_load=1; ciccratchcoupon=%5B%5D; form_key=YOxDtVwqt8GnnBJf; cdz-newsletter-modal=1lax; PHPSESSID=1alid9cu064qlgltblik2rggel; form_key=YOxDtVwqt8GnnBJf; mage-cache-storage=%7B%7D; mage-cache-storage-section-invalidation=%7B%7D; mage-cache-sessid=true; searchsuiteautocomplete=%7B%7D; recently_viewed_product=%7B%7D; recently_viewed_product_previous=%7B%7D; recently_compared_product=%7B%7D; recently_compared_product_previous=%7B%7D; product_data_storage=%7B%7D; section_data_ids=%7B%22cart%22%3A1670249243%7D; _hjIncludedInSessionSample=0; _hjSession_2526921=eyJpZCI6ImQxOGU3YjlmLTc0ZWQtNDY4ZS1hNGNlLTdlMzUzOGNhYmEzOSIsImNyZWF0ZWQiOjE2NzAyNTIzNzEzMjIsImluU2FtcGxlIjpmYWxzZX0=; _hjAbsoluteSessionInProgress=0; private_content_version=2a1ec34197547510397823f82e512e07',
    'Referer': 'https://www.google.com/',
    'Sec-Fetch-Dest': 'document',
    'Sec-Fetch-Mode': 'navigate',
    'Sec-Fetch-Site': 'cross-site',
    'Sec-Fetch-User': '?1',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Mobile Safari/537.36',
    'sec-ch-ua': '"Not?A_Brand";v="8", "Chromium";v="108", "Google Chrome";v="108"',
    'sec-ch-ua-mobile': '?1',
    'sec-ch-ua-platform': '"Android"',
}



    response = requests.get(url, cookies=cookies, headers=headers)
    return response


def get_spec_json(sel):
    spec_json = {}
    for spec_title, spec_sku in zip(spec_titles, spec_skus):
        spec_json[spec_title.strip().lower()] = spec_sku
    return spec_json

# %%
urls ='''https://www.poojaratele.com/brand/oppo/oppo-enco-w11-true-wireless-bluetooth-headset-white.html
https://www.poojaratele.com/brand/oppo/oppo-enco-m32-bluetooth-wireless-neckband-black.html
https://www.poojaratele.com/brand/oppo/oppo-enco-m32-bluetooth-wireless-neckband-green.html
https://www.poojaratele.com/brand/oppo/oppo-smart-band-style-black.html
https://www.poojaratele.com/brand/oppo/oppo-enco-w31-true-wireless-bluetooth-headset-white.html
https://www.poojaratele.com/brand/oppo/oppo-enco-air2-pro-true-wireless-earbuds-gray.html
https://www.poojaratele.com/brand/oppo/oppo-enco-air2-pro-true-wireless-earbuds-white.html
https://www.poojaratele.com/brand/oppo/oppo-enco-w51-true-wireless-earphone-floral-white.html
https://www.poojaratele.com/brand/oppo/oppo-enco-w51-true-wireless-earphone-starry-blue.html
https://www.poojaratele.com/brand/oppo/oppo-a16k-black-3gb-32gb.html
https://www.poojaratele.com/brand/oppo/oppo-a16k-white-3gb-32gb.html
https://www.poojaratele.com/brand/oppo/oppo-a16e-blue-3gb-32gb.html
https://www.poojaratele.com/brand/oppo/oppo-enco-x-with-noise-cancelling-bluetooth-headset-white.html
https://www.poojaratele.com/brand/oppo/oppo-a16e-midnight-black-3gb-32gb.html
https://www.poojaratele.com/brand/oppo/oppo-a16e-white-3gb-32gb.html
https://www.poojaratele.com/brand/oppo/oppo-a17k-navy-blue-3gb-64gb.html
https://www.poojaratele.com/brand/oppo/oppo-a17-midnight-black-4gb-64gb.html
https://www.poojaratele.com/brand/oppo/oppo-a17-sunlight-orange-4gb-64gb.html
https://www.poojaratele.com/brand/oppo/oppo-a57-glowing-gold-4gb-64gb.html
https://www.poojaratele.com/brand/oppo/oppo-a77-sky-blue-4gb-64gb.html
https://www.poojaratele.com/brand/oppo/oppo-a16e-blue-4gb-64gb.html
https://www.poojaratele.com/brand/oppo/oppo-a16e-midnight-black-4gb-64gb.html
https://www.poojaratele.com/brand/oppo/oppo-a16e-white-4gb-64gb.html
https://www.poojaratele.com/brand/oppo/oppo-a77-sky-blue-4gb-128gb.html
https://www.poojaratele.com/brand/oppo/oppo-a77-sunset-orange-4gb-128gb.html
https://www.poojaratele.com/brand/oppo/oppo-a16-pearl-blue-4gb-64gb.html
https://www.poojaratele.com/brand/oppo/oppo-a16-crystal-black-4gb-64gb.html
https://www.poojaratele.com/brand/oppo/oppo-a57-glowing-black-4gb-64gb.html
https://www.poojaratele.com/brand/oppo/oppo-a57-glowing-green-4gb-64gb.html
https://www.poojaratele.com/brand/oppo/oppo-a76-glowing-black-6gb-128gb.html
https://www.poojaratele.com/brand/oppo/oppo-a76-glowing-blue-6gb-128gb.html
https://www.poojaratele.com/brand/oppo/oppo-a77s-sunset-orange-8gb-128gb.html
https://www.poojaratele.com/brand/oppo/oppo-a77s-starry-black-8gb-128gb.html
https://www.poojaratele.com/brand/oppo/oppo-a96-starry-black-8gb-128gb.html
https://www.poojaratele.com/brand/oppo/oppo-a96-sunset-blue-8gb-128gb.html
https://www.poojaratele.com/brand/oppo/oppo-pad-air-grey-4gb-128gb.html
https://www.poojaratele.com/brand/oppo/oppo-f21-pro-cosmic-black-8gb-128gb.html
https://www.poojaratele.com/brand/oppo/oppo-f21-pro-sunset-orange-8gb-128gb.html
https://www.poojaratele.com/brand/oppo/oppo-f21s-pro-dawnlight-gold-8gb-128gb.html
https://www.poojaratele.com/brand/oppo/oppo-f21s-pro-starlight-black-8gb-128gb.html
https://www.poojaratele.com/brand/oppo/oppo-f21s-pro-5g-starlight-black-8gb-128gb.html
https://www.poojaratele.com/brand/oppo/oppo-f21s-pro-5g-dawnlight-gold-8gb-128gb.html
https://www.poojaratele.com/brand/oppo/oppo-reno6-5g-aurora-8-gb-128-gb.html
https://www.poojaratele.com/brand/oppo/oppo-f21-pro-5g-cosmic-black-8gb-128gb.html
https://www.poojaratele.com/brand/oppo/oppo-f21-pro-5g-rainbow-spectrum-8gb-128gb.html
https://www.poojaratele.com/brand/oppo/oppo-reno7-5g-starry-black-8gb-256gb.html
https://www.poojaratele.com/brand/oppo/oppo-reno7-5g-startrails-blue-8gb-256gb.html
https://www.poojaratele.com/brand/oppo/oppo-reno8-5g-shimmer-black-8gb-128gb.html
https://www.poojaratele.com/brand/oppo/oppo-reno8-5g-shimmer-gold-8gb-128gb.html
https://www.poojaratele.com/brand/oppo/oppo-reno7-pro-5g-startrails-blue-12gb-256gb.html
https://www.poojaratele.com/brand/oppo/oppo-reno7-pro-5g-starlight-black-12gb-256gb.html'''.split("\n") #split is use to convert to the  single List.

urls = set(urls)
len(urls) #to check length of urls
# Out:
# 51

# %%
# res = response
# res

# %%
# texts = res.text
# texts

# %%
# sel = Selector(res)
# sel

# %%
# " ".join(sel.xpath('//*/div[@class="product attribute sku"]/div//text()').extract()).strip() #to check indivisuly xpath data

# %%
items = []
for url in tqdm(urls):
    res = get_res(url)
    sel = Selector(res)
    item = {} #.join all the item in dict.
    item['title'] = " ".join(sel.xpath('//*/h1[contains(@class,"page-title")]//text()').extract()).strip()
    item['SKU'] = " ".join(sel.xpath('//*/div[contains(@class,"product attribute sku")]/div/text()').extract()).strip()
    item['final_price']= " ".join(sel.xpath('(//*/span[contains(@id,"product-price")]/span//text())[1]').extract()).strip()#The strip() method removes any leading (spaces at the beginning) and trailing (spaces at the end) 
    item['old_price']= " ".join(sel.xpath('(//*/span[contains(@id,"old-price")]/span//text())[1]').extract()).strip()  #xpath using indexing for choose multipal value 
    item['url'] = url
    
    items.append(item)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 51/51 [01:20<00:00,  1.58s/it]

# %%
items
# Out:
# [{'title': 'Oppo Reno7 Pro 5G (Startrails Blue, 12GB, 256GB)',
#   'SKU': '6932169303422',
#   'final_price': '₹47,990.00',
#   'old_price': '',
#   'url': 'https://www.poojaratele.com/brand/oppo/oppo-reno7-pro-5g-startrails-blue-12gb-256gb.html'},
#  {'title': 'Oppo Reno7 Pro 5G (Starlight Black, 12GB, 256GB)',
#   'SKU': '6932169302357',
#   'final_price': '₹47,990.00',
#   'old_price': '',
#   'url': 'https://www.poojaratele.com/brand/oppo/oppo-reno7-pro-5g-starlight-black-12gb-256gb.html'},
#  {'title': 'OPPO F21 Pro (Sunset Orange, 8GB, 128GB)',
#   'SKU': '6932169307864',
#   'final_price': '₹21,999.00',
#   'old_price': '₹27,999.00',
#   'url': 'https://www.poojaratele.com/brand/oppo/oppo-f21-pro-sunset-orange-8gb-128gb.html'},
#  {'title': 'Oppo A16K (Black, 3GB, 32GB)',
#   'SKU': '6944284695832',
#   'final_price': '₹8,999.00',
#   'old_price': '₹13,990.00',
#   'url': 'https://www.poojaratele.com/brand/oppo/oppo-a16k-black-3gb-32gb.html'},
# ...

# %%
df = pd.DataFrame(items)
df                        #create data frame using pandas
# Out:
#                                                 title                  SKU  \
# 0    Oppo Reno7 Pro 5G (Startrails Blue, 12GB, 256GB)        6932169303422
# 1    Oppo Reno7 Pro 5G (Starlight Black, 12GB, 256GB)        6932169302357
# 2            OPPO F21 Pro (Sunset Orange, 8GB, 128GB)        6932169307864
# 3                        Oppo A16K (Black, 3GB, 32GB)        6944284695832
# 4      OPPO F21 Pro 5G (Rainbow Spectrum, 8GB, 128GB)        6932169306607
# 5                OPPO A77s (Starry Black, 8GB, 128GB)        6932169320160
# 6           OPPO Reno8 5G (Shimmer Black, 8GB, 128GB)        6932169315258
# 7                  Oppo A96 (Sunset Blue, 8GB, 128GB)        6932169305563
# 8   OPPO ENCO W51 True Wireless Earphone (Starry B...        6944284665118
# 9                    OPPO A17k (Navy Blue, 3GB, 64GB)        6932169319140
# 10              OPPO A16e (Midnight Black, 4GB, 64GB)        6932169308991
# ...

# %%
#df.to_csv('Oppo_data.csv', index= False) #now create excel file
